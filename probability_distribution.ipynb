# %% [markdown]
# <a href="https://colab.research.google.com/github/EmmanuelGbafore/Pantech-Solution_Data-Analytics-Master-Class/blob/main/probability_distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Binomial Distribution

# !pip install scipy
from scipy.stats import binom
import matplotlib.pyplot as plt

num_trials = 10
heads_probability = 0.5

# Calculate probability mass function (PMF) values
probs = [binom.pmf(i, num_trials, heads_probability) for i in range(11)]  # Assign PMF values to 'probs'

# Plot the distribution
plt.stem(list(range(11)), probs)
plt.xlabel("Number of Heads")
plt.ylabel("Probability")
plt.title("Binomial Distribution for 10 Coin Tosses (p=0.5)")
plt.show()

# %%
# Poisson Distribution

from scipy.stats import poisson
rate = 33

probs = [poisson.pmf (i,rate) for i in range (15)]         # probability mass function
plt.stem (list (range(15)), probs)
# Out:
# <StemContainer object of 3 artists>
